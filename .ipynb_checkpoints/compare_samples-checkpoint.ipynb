# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
samples = np.loadtxt('training_data/training_samples.txt')
samples_wide = np.loadtxt('experiments/training_data/training_samples.txt')

# %%
logzeta0 = samples[:,0]
logzeta0_wide = samples_wide[:,0]

# %%
plt.hist(logzeta0,bins='auto',alpha=0.5)
plt.hist(logzeta0_wide,bins='auto',alpha=0.5)
plt.yscale('log')
